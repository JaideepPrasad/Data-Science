# %%
def preprocessing(file):
    df_a = pd.read_excel(file)                                         # import data
    col = df_a.columns[0]                                              # get name of colum in df
    df_a.drop_duplicates(subset = col, keep = "first", inplace = True) # get rid of duplicates
    df_a = df_a.reset_index(drop=True)                                 # reset index
    df_a = df_a.iloc[:,0].str.lower().str.replace(" ", "")             # .lower makes input lowercase, .replace gets rid of space
    return df_a

# %%
def word2vec(df):
    
    token = list(df.values) # tokenize names

    for names in token:
        #print(names)
        count_char = Counter(names)                               # creates set containing char & number of char occurancs 
        char = set(count_char)                                    # creates set of char in name
        lenght = math.sqrt(sum(x*x for x in count_char.values())) # magnitude of word vec(for cosine eq), each dim is a letter in name
        yield count_char, char, lenght, names

# %%
def cosine_similarity(vector1, vector2):
    
    common_char = vector1[1].intersection(vector2[1])                 # common letters between both names/vectors
    dot_product = sum(vector1[0][char] * vector2[0][char] for char in common_char) # dot product (for cosin eq)
    total_length = vector1[2] * vector2[2]                            # total lenght of vectors
    if total_length == 0:                                             # condition so we don't divide by zero in cosign eq 
        similarity = 0
    else:
        similarity = round(dot_product/total_length, 3)               # similar letters/all letters to 3 decimal places
    return similarity

# %%
def name_matching(file1, file2, similarity_threshold):              # our 'main' function
    
    results = []                                                    # list that holds results
    
    df1 = preprocessing(file1)                                      # preprocess data from files 1 and 2
    df2 = preprocessing(file2)
    
    vectorization = word2vec(df1)                                   # vectorize data form df 1 and 2
    w2v1 = [v for v in vectorization]
    vectorization = word2vec(df2)
    w2v2 = [v for v in vectorization]
    
    for x in w2v1:                                                   # compare every name from df1 with every name from df 2
        for y in w2v2:
            score = cosine_similarity(x, y)                          # get similarity score
            if similarity_threshold <= score <= 1:                   # if score is within threshold, add it to our results
                results.append([x[3], y[3], score])                  # (name 1, name 2, similarity score of name 1 and 2)
    
    results_df = pd.DataFrame(results)                                           # turn into a dataframe (output looks nice)
    if len(results_df) != 0:                                                                     # safety condition
        results_df.columns = ['First Name', 'Second Name', 'Cosine Similarity Score']            # name colums
    results_df = results_df.sort_values(by = 'Cosine Similarity Score', ascending=False)         # sort names based on score
    results_df = results_df.reset_index(drop=True)                                               # reset the index
    return results_df

# %%
import pandas as pd
from collections import Counter
import math

a = "File_A.xlsx"
b = "File_B.xlsx"

name_matching(a, b, 0.9) # looks for 90% cosing similarity
# Out:
#                                    First Name          Second Name  \
# 0                                     prakash              prakash
# 1                                baughwilliam         baughwilliam
# 2                              robertweissman       robertweissman
# 3                                ralphsteiger         ralphsteiger
# 4                            andrewhesseltine     andrewhesseltine
# 5                                   lavisimon            lavisimon
# 6                              abrahamishaaya       abrahamishaaya
# 7                                   lavisimon            lavismion
# 8                                    marcwaki             marcwaki
# 9                                      robert               robert
# 10                                michaelport          michaelport
# 11                             mikulakstephen       mikulakstephen
# 12                                farshiramin         imransharief
# 13                                     robert         roberttorrey
# 14                                  lavisimon           lavissimon
# 15                               ralphsteiger     orthralphsteiger
# 16                             mikulakstephen       milulakstephen
# 17                                     bittar              torbati
# 18                             abrahamishaaya     abraamyanabraham
# 19                             breathemedical      heathermcdaniel
# 20                             breathemedical          adamleicher
# 21                                  lavisimon          dnsimonlavi
# 22                                  lavisimon          lavidosimon
# 23                   orthopedicrehabilitation          patelrohini
# 24                           andrewhesseltine    edwardlewissteven
# 25                                     robert          gorabrobert
# 26  corporationmanagementmedicalpainuniversal         marcianelson
# 27                                     bittar          bittartarek
# 28                            physicaltherapy          ashleyprait
# 29                             abrahamishaaya          arasharyana
# 30                                     robert          robertruder
# 31                           andrewhesseltine  andrewsrahilasteele
# 32                           andrewhesseltine           hesseltine
# 33                                     bittar           roberttait
# 34                                     robert           robertruth
# 35                    anklecentersfootmedical     constancekeibler
# 36                                farshiramin           mirfakhrai
# 37                   grouphealthpointemedical          michaelport
# 38                 physicalrozinasmiththerapy          ashleyprait
# 39                             robertweissman         norristeresa
# 40                             breathemedical         bakermichael
# 41                                     robert         grumetrobert
# 42                                     robert         katzerrobert
# 43                                     robert         ozeranrobert
# 44       groupintegratedmanagementmedicalpain      endrigagemmalin
# 45                           andrewhesseltine     danielstephenson
# 46              anesthesiageneralpartnersspec  andrewsrahilasteele
# 47               americacorporationlaboratory     altamiranovictor
# 48                                farshiramin       amritakrishnan
# 49                           andrewhesseltine         stvenwheeler
# 50               americacorporationlaboratory         coopermartin
# 51               americacorporationlaboratory       bartoncornelia
# 52                                     robert         hookerrobert
# 53   advancedcancerdermatologyskinspecialists   callcarediagnostic
# 54                           andrewhesseltine          harnessneil
# 55                                 anesthesia      kasimianstephen
# 56           centercoastmanagementpacificpain        castlemaneric
# 57                      chaparralgroupmedical       allenchadprior
#
#     Cosine Similarity Score
# 0                     1.000
# 1                     1.000
# 2                     1.000
# 3                     1.000
# 4                     1.000
# 5                     1.000
# 6                     1.000
# 7                     1.000
# 8                     1.000
# 9                     1.000
# 10                    1.000
# 11                    1.000
# 12                    0.972
# 13                    0.968
# 14                    0.967
# 15                    0.945
# 16                    0.944
# 17                    0.943
# 18                    0.940
# 19                    0.938
# 20                    0.936
# 21                    0.934
# 22                    0.934
# 23                    0.927
# 24                    0.926
# 25                    0.926
# 26                    0.926
# 27                    0.926
# 28                    0.925
# 29                    0.924
# 30                    0.919
# 31                    0.917
# 32                    0.917
# 33                    0.917
# 34                    0.917
# 35                    0.915
# 36                    0.910
# 37                    0.909
# 38                    0.906
# 39                    0.906
# 40                    0.906
# 41                    0.905
# 42                    0.905
# 43                    0.905
# 44                    0.904
# 45                    0.904
# 46                    0.904
# 47                    0.904
# 48                    0.904
# 49                    0.902
# 50                    0.902
# 51                    0.902
# 52                    0.901
# 53                    0.901
# 54                    0.900
# 55                    0.900
# 56                    0.900
# 57                    0.900
